# %%
#Eugene Fotsing
#CTEC298
#Jupiter Notebook
#Panda Tutorial

# %%
#tutorial 1
import pandas as pd

#create a virtual representation of a dataset
df = pd.read_csv('C:\\Users\\eugen\\OneDrive\\Desktop\\weather files.csv')
df
# Out:
#              name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0   weather files  11/10/2024     13.1      9.0  11.4          13.1
# 1   weather files  11/11/2024     10.2      4.4   7.2          10.2
# 2   weather files  11/12/2024      5.4      2.0   4.2           5.4
# 3   weather files  11/13/2024     11.6      2.9   7.0          11.6
# 4   weather files  11/14/2024     12.2      6.3   8.8          12.2
# 5   weather files  11/15/2024     11.3      5.3   8.8          11.3
# 6   weather files  11/16/2024     10.6      7.1   8.9          10.6
# 7   weather files  11/17/2024     10.9      7.7   9.4          10.9
# 8   weather files  11/18/2024     11.6      9.7  10.6          11.6
# 9   weather files  11/19/2024     11.7      5.9   9.2          11.7
# 10  weather files  11/20/2024      6.0      2.0   4.5           5.6
# 11  weather files  11/21/2024      5.5      1.4   2.8           3.5
# 12  weather files  11/22/2024      2.9     -1.3   0.7           0.1
# ...

# %%
#looking for the maximum temperature
df['tempmax'].max()
# Out:
# 13.1

# %%
#lookin for column with condition
df['datetime'][df['temp']!='10']
# Out:
# 0     11/10/2024
# 1     11/11/2024
# 2     11/12/2024
# 3     11/13/2024
# 4     11/14/2024
# 5     11/15/2024
# 6     11/16/2024
# 7     11/17/2024
# 8     11/18/2024
# 9     11/19/2024
# 10    11/20/2024
# 11    11/21/2024
# 12    11/22/2024
# 13    11/23/2024
# 14    11/24/2024
# Name: datetime, dtype: object

# %%
#Wrangling the data by replace the empty with a zero
df.fillna(0,inplace=True)

# %%
df
# Out:
#              name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0   weather files  11/10/2024     13.1      9.0  11.4          13.1
# 1   weather files  11/11/2024     10.2      4.4   7.2          10.2
# 2   weather files  11/12/2024      5.4      2.0   4.2           5.4
# 3   weather files  11/13/2024     11.6      2.9   7.0          11.6
# 4   weather files  11/14/2024     12.2      6.3   8.8          12.2
# 5   weather files  11/15/2024     11.3      5.3   8.8          11.3
# 6   weather files  11/16/2024     10.6      7.1   8.9          10.6
# 7   weather files  11/17/2024     10.9      7.7   9.4          10.9
# 8   weather files  11/18/2024     11.6      9.7  10.6          11.6
# 9   weather files  11/19/2024     11.7      5.9   9.2          11.7
# 10  weather files  11/20/2024      6.0      2.0   4.5           5.6
# 11  weather files  11/21/2024      5.5      1.4   2.8           3.5
# 12  weather files  11/22/2024      2.9     -1.3   0.7           0.1
# ...

# %%
#tutorial 2

#create a dataframe & Operations

df = pd.read_csv('C:\\Users\\eugen\\OneDrive\\Desktop\\weather files.csv')

# %%
df
# Out:
#              name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0   weather files  11/10/2024     13.1      9.0  11.4          13.1
# 1   weather files  11/11/2024     10.2      4.4   7.2          10.2
# 2   weather files  11/12/2024      5.4      2.0   4.2           5.4
# 3   weather files  11/13/2024     11.6      2.9   7.0          11.6
# 4   weather files  11/14/2024     12.2      6.3   8.8          12.2
# 5   weather files  11/15/2024     11.3      5.3   8.8          11.3
# 6   weather files  11/16/2024     10.6      7.1   8.9          10.6
# 7   weather files  11/17/2024     10.9      7.7   9.4          10.9
# 8   weather files  11/18/2024     11.6      9.7  10.6          11.6
# 9   weather files  11/19/2024     11.7      5.9   9.2          11.7
# 10  weather files  11/20/2024      6.0      2.0   4.5           5.6
# 11  weather files  11/21/2024      5.5      1.4   2.8           3.5
# 12  weather files  11/22/2024      2.9     -1.3   0.7           0.1
# ...

# %%
weather_file = {
    "day": ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    "temperature": [32,35,28,24,32,31],
    "windspeed": [6,7,2,7,4,2],
    "event": ['Rain','Sunny','Snow','Snow','Rain','Sunny']
}
tp = pd.DataFrame(weather_file)
tp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       1 weather_file = {
#       2     "day": ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
#       3     "temperature": [32,35,28,24,32,31],
#       4     "windspeed": [6,7,2,7,4,2],
#       5     "event": ['Rain','Sunny','Snow','Snow','Rain','Sunny']
#       6 }
# ----> 7 tp = pd.DataFrame(weather_file)
#       8 tp
#
# NameError: name 'pd' is not defined

# %%
tp.shape
# Out:
# (6, 4)

# %%
tp.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
tp.tail()
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
tp[2:]
# Out:
#         day  temperature  windspeed  event
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
tp.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
tp.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
#applying a selection of column
tp[['event','day','temperature']]
# Out:
#    event       day  temperature
# 0   Rain  1/1/2017           32
# 1  Sunny  1/2/2017           35
# 2   Snow  1/3/2017           28
# 3   Snow  1/4/2017           24
# 4   Rain  1/5/2017           32
# 5  Sunny  1/6/2017           31

# %%
tp['temperature'].max()
# Out:
# 35

# %%
tp.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
tp[tp.temperature>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
#Set index

tp.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
tp.set_index('day', inplace=True)
tp
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
tp.loc['1/3/2017']
# Out:
# temperature      28
# windspeed         2
# event          Snow
# Name: 1/3/2017, dtype: object

# %%
#Reset an index plaec before
tp.reset_index(inplace=True)
tp
# Out:
#    index       day  temperature  windspeed  event
# 0      0  1/1/2017           32          6   Rain
# 1      1  1/2/2017           35          7  Sunny
# 2      2  1/3/2017           28          2   Snow
# 3      3  1/4/2017           24          7   Snow
# 4      4  1/5/2017           32          4   Rain
# 5      5  1/6/2017           31          2  Sunny

# %%
tp.set_index('event',inplace=True)
tp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tp
#
# NameError: name 'tp' is not defined
